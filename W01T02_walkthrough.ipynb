# %% [markdown]
# # Week 1 · Topic 2 — Variables and Types
#
# **Box we are building: a first look at STORE**
#
# By the end of this notebook you can store a value, use it again, and say what type it is.
#
# > **Already know this?** Skip to the *Topic 2 Challenge*.

# %% [markdown]
# ---
# ## 1. A variable is a name for a value
#
# Read `=` as **"gets"**, not "equals".
# `value = 23.7` means *put 23.7 into value*.

# %%
record_id = "R-004"
value = 23.7
limit = 20

print(record_id)
print(value)
print(limit)
# Out:
# R-004
# 23.7
# 20

# %% [markdown]
# Once stored, use the **name** wherever you would use the value.

# %%
print(record_id, "has value", value)
# Out:
# R-004 has value 23.7

# %% [markdown]
# ### Your turn
# Store your own name in `student_name` and your course in `course`, then print both in one line.

# %%
student_name = "Zainab Irfan"
course = "CST1510"
print("My name is", student_name, "and I am taking", course)
# Out:
# My name is Zainab Irfan and I am taking CST1510

# %% [markdown]
# ---
# ## 2. Types
#
# Every value has a type. Ask Python with `type()`.

# %%
print(type(record_id))
print(type(value))
print(type(limit))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>

# %% [markdown]
# | Type | Means |
# |---|---|
# | `str` | text |
# | `int` | whole number |
# | `float` | number with a decimal point |

# %% [markdown]
# ### The thing that catches everyone
#
# These two print identically. They are **not** the same.

# %%
text_twenty = "20"
number_twenty = 20

print(text_twenty)
print(number_twenty)
# Out:
# 20
# 20

# %%
print(type(text_twenty))
print(type(number_twenty))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ### Your turn
# Run the next cell. **Before you run it**, write down what you expect. Then explain the result to the person next to you.

# %%
print("20" + "20")
print(20 + 20)
# Out:
# 2020
# 40

# %%
2020 #the two strings are being concatenated, while the two numbers are being added together.
40

# %% [markdown]
# ---
# ## 3. Naming
#
# Names should say what the value *is*.
#
# Rules: lowercase, underscores between words, no spaces, cannot start with a digit, cannot be a Python word such as `print`, `if` or `class`.

# %%
# hard to read later
v = 23.7
l = 20

# easy to read later
sensor_value = 23.7
sensor_limit = 20

print(v - l)
print(sensor_value - sensor_limit)
# Out:
# 3.6999999999999993
# 3.6999999999999993

# %% [markdown]
# ### Your turn
# The next cell has three bad names. Rewrite it with good ones. The output should not change.

# %%
x = "srv-01"
y = 87
z = 100
print(x, y, z)
# Out:
# srv-01 87 100

# %%
StudentCode = "srv-01" # variable name is meaningful , easier for next person to understand
StudentScore1 = 87 
StudentScore2 = 100
print (StudentCode, StudentScore1, StudentScore2)
# Out:
# srv-01 87 100

# %% [markdown]
# ---
# ## 4. Reassigning
#
# A variable can be given a new value. The old one is gone.

# %%
checks_done = 0
print(checks_done)

checks_done = 1
print(checks_done)

checks_done = 2
print(checks_done)
# Out:
# 0
# 1
# 2

# %% [markdown]
# ### Your turn
# Without running it, what does this print? Write your answer down, then run it.

# %%
a = 5
b = 10
a = b
b = 3
print(a, b)

# a should be 10 and b should be 3
# Out:
# 10 3

# %% [markdown]
# ---
# ## Topic 2 Challenge
#
# Store these four facts about one server in sensibly named variables, then print a single line reading:
#
# ```
# srv-01 in London is 87% full
# ```
#
# - hostname: `srv-01`
# - location: `London`
# - disk used: `87`
# - (you decide what to call the `%` sign)

# %%
HostName = "srv-01"
Location = "london"
DiskUsed = 87 
PercentageSign = "%"

print(HostName, "in" , Location, "is", DiskUsed, PercentageSign, "full")
# Out:
# srv-01 in london is 87 % full

# %% [markdown]
# ---
# ## Same idea, three fields
#
# A variable holds one fact about one thing.
#
# | Field | Looks like |
# |---|---|
# | **AI / Data Science** | `reading = 23.7`, `units = "celsius"` |
# | **Cyber Security** | `source_ip = "10.0.0.5"`, `port = 443` |
# | **IT** | `hostname = "srv-01"`, `disk_used = 87` |

# %% [markdown]
# ---
# ## Common mistakes
#
# | Mistake | What you see | Fix |
# |---|---|---|
# | `23.7 = value` | `SyntaxError` | the name goes on the **left** |
# | `my value = 3` | `SyntaxError` | no spaces — `my_value` |
# | using a name you never set | `NameError` | assign it before you use it |
# | `"20" + 5` | `TypeError` | text and number — convert first (Topic 4) |
#
# > When something behaves oddly, **print the type**. It is almost always this.
#
# ## Go deeper
#
# `examples/01_variables.py` — naming rules, reassignment, order of assignment
# `examples/02_types.py` — why the type decides what an operator *does*

# %% [markdown]
# ---
# ## Recap
#
# | You can now | Using |
# |---|---|
# | store a value | `name = value` |
# | check a type | `type(x)` |
# | tell text from numbers | `"20"` vs `20` |
# | name things well | `sensor_value`, not `v` |
#
# **Next:** Topic 3 — doing arithmetic with what you stored.
